# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("breast.csv")
df
# Out:
#        sex  year  primarysite  histo  grade  laterality  stage  chemo    time  \
# 0        1  2011          508      9    2.0         2.0    1.0      0  1860.5
# 1        1  2012          508      8    NaN         1.0    1.0      0  1738.5
# 2        1  2013          504      9    3.0         2.0    3.0      1  1220.0
# 3        1  2011          503      9    3.0         1.0    5.0      0  1738.5
# 4        1  2012          501      6    1.0         2.0    1.0      0  1738.5
# ...    ...   ...          ...    ...    ...         ...    ...    ...     ...
# 37813    1  2016          508      9    3.0         1.0    NaN      0     0.0
# 37814    1  2016          504      9    2.0         1.0    NaN      1   274.5
# 37815    1  2016          504      9    2.0         1.0    NaN      0    30.5
# 37816    1  2016          501     11    2.0         1.0    NaN      1   152.5
# 37817    1  2014          508      9    3.0         2.0    1.0      0   915.0
#
# ...

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37818 entries, 0 to 37817
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sex          37818 non-null  int64
#  1   year         37818 non-null  int64
#  2   primarysite  37818 non-null  int64
#  3   histo        37818 non-null  int64
#  4   grade        35977 non-null  float64
#  5   laterality   37725 non-null  float64
#  6   stage        31825 non-null  float64
#  7   chemo        37818 non-null  int64
#  8   time         37818 non-null  float64
#  9   totnumb      37818 non-null  int64
#  10  race         37570 non-null  float64
#  11  spanish      37818 non-null  int64
#  12  age          37818 non-null  int64
#  13  mondiag      37818 non-null  int64
#  14  mari         35787 non-null  float64
#  15  nomindex     37814 non-null  float64
#  16  t            29788 non-null  float64
#  17  n            31540 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# sex               0
# year              0
# primarysite       0
# histo             0
# grade          1841
# laterality       93
# stage          5993
# chemo             0
# time              0
# totnumb           0
# race            248
# spanish           0
# age               0
# mondiag           0
# mari           2031
# nomindex          4
# t              8030
# n              6278
# m              5664
# surg             44
# death             0
# radio          3206
# dtype: int64

# %%
df.describe()
# Out:
#                 sex          year   primarysite         histo         grade  \
# count  37818.000000  37818.000000  37818.000000  37818.000000  35977.000000
# mean       0.998625   2012.995531    505.112671      8.796790      2.791728
# std        0.037056      1.996270      2.472788      1.322392      0.469566
# min        0.000000   2010.000000    500.000000      1.000000      1.000000
# 25%        1.000000   2011.000000    504.000000      9.000000      3.000000
# 50%        1.000000   2013.000000    504.000000      9.000000      3.000000
# 75%        1.000000   2015.000000    508.000000      9.000000      3.000000
# max        1.000000   2016.000000    509.000000     11.000000      4.000000
#
#          laterality         stage         chemo          time       totnumb  \
# count  37725.000000  31825.000000  37818.000000  37818.000000  37818.000000
# mean       1.487714      3.209772      0.746364   1030.422233      1.090433
# ...

# %%
df.mean(numeric_only=True)
# Out:
# sex               0.998625
# year           2012.995531
# primarysite     505.112671
# histo             8.796790
# grade             2.791728
# laterality        1.487714
# stage             3.209772
# chemo             0.746364
# time           1030.422233
# totnumb           1.090433
# race              1.436705
# spanish           0.128695
# age              58.212782
# mondiag           6.481173
# mari              1.819320
# nomindex       1027.122362
# t                 6.270881
# n                 0.559543
# m                 0.056976
# surg              0.897496
# death             0.200301
# radio             0.530018
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# sex               1.0
# year           2013.0
# primarysite     504.0
# histo             9.0
# grade             3.0
# laterality        1.0
# stage             3.0
# chemo             1.0
# time            915.0
# totnumb           1.0
# race              1.0
# spanish           0.0
# age              58.0
# mondiag           6.0
# mari              1.0
# nomindex       1040.0
# t                 7.0
# n                 0.0
# m                 0.0
# surg              1.0
# death             0.0
# radio             1.0
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#    sex  year  primarysite  histo  grade  laterality  stage  chemo  time  \
# 0    1  2011          504      9    3.0         1.0    1.0      1  30.5
#
#    totnumb  ...  age  mondiag  mari  nomindex    t    n    m  surg  death  \
# 0        1  ...   53       10   1.0    1117.0  7.0  0.0  0.0   1.0      0
#
#    radio
# 0    1.0
#
# [1 rows x 22 columns]

# %%
df.var(numeric_only=True)
# Out:
# sex                 0.001373
# year                3.985093
# primarysite         6.114681
# histo               1.748720
# grade               0.220492
# laterality          0.250333
# stage               4.323390
# chemo               0.189310
# time           527768.976156
# totnumb             0.097488
# race                0.689398
# spanish             0.112136
# age               197.252366
# mondiag            11.705082
# mari                1.150833
# nomindex        28087.605660
# t                   3.564349
# n                   0.757639
# m                   0.053731
# surg                0.092000
# death               0.160185
# radio               0.249106
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# sex              0.037056
# year             1.996270
# primarysite      2.472788
# histo            1.322392
# grade            0.469566
# laterality       0.500333
# stage            2.079276
# chemo            0.435097
# time           726.477100
# totnumb          0.312231
# race             0.830300
# spanish          0.334867
# age             14.044656
# mondiag          3.421269
# mari             1.072769
# nomindex       167.593573
# t                1.887948
# n                0.870425
# m                0.231800
# surg             0.303314
# death            0.400231
# radio            0.499105
# dtype: float64

# %%
df.cov(numeric_only=True)
# Out:
#                   sex         year  primarysite      histo     grade  \
# sex          0.001373    -0.001090    -0.001458   0.001492 -0.000010
# year        -0.001090     3.985093    -0.054181   0.006813 -0.004382
# primarysite -0.001458    -0.054181     6.114681  -0.233311 -0.004194
# histo        0.001492     0.006813    -0.233311   1.748720  0.021898
# grade       -0.000010    -0.004382    -0.004194   0.021898  0.220492
# laterality   0.000063    -0.004264     0.025618  -0.006638 -0.000254
# stage       -0.002268    -0.000139     0.704759  -0.229648  0.120043
# chemo        0.000154     0.036178    -0.026847   0.019457  0.036356
# time         0.757145 -1109.780327   -89.653929  28.318874 -7.595433
# totnumb      0.000071    -0.042910     0.002477   0.000661 -0.006751
# race        -0.000247     0.037897     0.001689   0.006197 -0.001270
# spanish      0.000098     0.019456     0.013899   0.002063  0.005698
# age         -0.008936     0.518734     0.296727  -0.388602 -0.949207
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                   sex      year  primarysite     histo     grade  laterality  \
# sex          1.000000 -0.014739    -0.015913  0.030453 -0.000623    0.003474
# year        -0.014739  1.000000    -0.010976  0.002581 -0.004669   -0.004270
# primarysite -0.015913 -0.010976     1.000000 -0.071349 -0.003647    0.020742
# histo        0.030453  0.002581    -0.071349  1.000000  0.039925   -0.010221
# grade       -0.000623 -0.004669    -0.003647  0.039925  1.000000   -0.001084
# laterality   0.003474 -0.004270     0.020742 -0.010221 -0.001084    1.000000
# stage       -0.030050 -0.000039     0.137416 -0.085679  0.125270    0.002264
# chemo        0.009530  0.041652    -0.024953  0.033817  0.178901   -0.000840
# time         0.028125 -0.765237    -0.049907  0.029478 -0.022286    0.009296
# totnumb      0.006177 -0.068843     0.003208  0.001600 -0.046018    0.006264
# race        -0.008012  0.022872     0.000823  0.005652 -0.003258   -0.005436
# ...

# %%
#handling the missing values(by putting the median in place of the missing values)
df.fillna(df.median(), inplace=True)
# Out:
#        sex  year  primarysite  histo  grade  laterality  stage  chemo    time  \
# 0        1  2011          508      9    2.0         2.0    1.0      0  1860.5
# 1        1  2012          508      8    3.0         1.0    1.0      0  1738.5
# 2        1  2013          504      9    3.0         2.0    3.0      1  1220.0
# 3        1  2011          503      9    3.0         1.0    5.0      0  1738.5
# 4        1  2012          501      6    1.0         2.0    1.0      0  1738.5
# ...    ...   ...          ...    ...    ...         ...    ...    ...     ...
# 37813    1  2016          508      9    3.0         1.0    3.0      0     0.0
# 37814    1  2016          504      9    2.0         1.0    3.0      1   274.5
# 37815    1  2016          504      9    2.0         1.0    3.0      0    30.5
# 37816    1  2016          501     11    2.0         1.0    3.0      1   152.5
# 37817    1  2014          508      9    3.0         2.0    1.0      0   915.0
#
# ...

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns
print(num_cols)
print(cat_cols)
# Out:
# Index(['sex', 'year', 'primarysite', 'histo', 'grade', 'laterality', 'stage',
#        'chemo', 'time', 'totnumb', 'race', 'spanish', 'age', 'mondiag', 'mari',
#        'nomindex', 't', 'n', 'm', 'surg', 'death', 'radio'],
#       dtype='str')
# Index([], dtype='str')

# %%
#Death analysis
df['death'].value_counts()
# Out:
# death
# 0    30243
# 1     7575
# Name: count, dtype: int64

# %%
#---PIE CHART-----(death v/s survival)
df['death'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Survival vs Death Distribution")
plt.ylabel('0[Survived] , 1[Death]')
plt.show()

# %%
#-----BAR GRAPH-----(Stage of cancer)
# df['stage'].value_counts().plot(kind='bar')
# plt.title("Cancer Stage Distribution")
# plt.xlabel("Stage")
# plt.ylabel("Count")
# plt.show()
df['stage'].value_counts().plot(kind='bar', colormap='viridis')

plt.title("Cancer Stage Distribution")
plt.xlabel("Stage")
plt.ylabel("Count")

plt.show()

# %%
#-----LINE GRAPH-----(year v/s time)
df.groupby('year')['time'].mean().plot(kind='line')
plt.title("Average Survival Time Over Years")
plt.xlabel("Year")
plt.ylabel("Avg Survival Time")
plt.show()

# %%
#----LINE PLOT GRAPH------(survival time v/s stage)
plt.figure(figsize=(10,7))
plt.plot(df['stage'].unique(), df.groupby('stage')['time'].sum(), marker='o', linestyle='-.', color='g')
plt.title("Total Survival Time per Cancer Stage")
plt.xlabel('Stage')
plt.ylabel('Total Survival Time')
plt.grid()
plt.show()

# %%
#---HISTOGRAM--(at what age happened)
# plt.hist(df['age'], bins=20)
# plt.title("Age Distribution")
# plt.xlabel("Age")
# plt.ylabel("Frequency")
# plt.show()
plt.hist(df['age'], bins=20, color='purple', edgecolor='black')

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
#-----SCATTER PLOT----(age v/s time)
# plt.scatter(df['age'], df['time'])
# plt.xlabel("Age")
# plt.ylabel("Survival Time")
# plt.title("Age vs Survival Time")
# plt.show()
plt.scatter(df['age'], df['time'], c=df['stage'], cmap='viridis')

plt.xlabel("Age")
plt.ylabel("Survival Time")
plt.title("Age vs Survival Time (Colored by Stage)")

plt.colorbar(label='Cancer Stage')

plt.show()

# %%
#-----HEATMAP----
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
#----PAIRPLOT----
sns.pairplot(df[['age', 'time', 't', 'n', 'm']])
plt.show()

# %%
#----COUNT PLOT----(count v/s tumor grade)
sns.countplot(x='grade', data=df, color='yellow')
plt.title("Tumor Grade Count")
plt.show()

# %%
#----BOX PLOT----(death v/s age)
sns.boxplot(x='death', y='age', data=df)
plt.title("Age Distribution by Survival")
plt.show()

# %%
#----VIOLINE PLOT----(age v/s stage)
sns.violinplot(x='stage', y='age', data=df, color='purple')
plt.title("Age Distribution Across Cancer Stages")
plt.show()

# %%
#----MACHINE LEARNING MODELs-------

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("breast.csv")

# Handle missing values
df.fillna(df.median(numeric_only=True), inplace=True)

# Features and target
X = df.drop('time', axis=1)
y = df['time']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#  Model 1: Linear Regression
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

print("Linear Regression Score:", lr.score(X_test, y_test))
# Out:
# Linear Regression Score: 0.8090404819145975

# %%
# Model 2: Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)

print("Random Forest Score:", rf.score(X_test, y_test))
# Out:
# Random Forest Score: 0.8565974802938013

# %%
print("Linear:", lr.score(X_test, y_test))
print("Random Forest:", rf.score(X_test, y_test))
# Out:
# Linear: 0.8090404819145975
# Random Forest: 0.8565974802938013
